# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("student_progress.csv")
df.head()
# Out:
#    student_id  skill_level  level_id      level_name  score  \
# 0           1            2         1   Python Basics   49.5
# 1           1            2         7        File I/O   62.4
# 2           1            2         9    OOP Advanced   38.0
# 3           1            2        10  Error Handling   45.5
# 4           1            2        14      Decorators   46.4
#
#    time_spent_minutes  attempts  passed  completion_order
# 0                27.2         4       0                 1
# 1                41.8         1       1                 2
# 2                39.7         2       0                 3
# 3                51.4         3       0                 4
# 4                56.6         4       0                 5

# %%
df.shape
# Out:
# (9572, 9)

# %%
df.isnull().sum()
# Out:
# student_id            0
# skill_level           0
# level_id              0
# level_name            0
# score                 0
# time_spent_minutes    0
# attempts              0
# passed                0
# completion_order      0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv("student_progress.csv", index= False)
